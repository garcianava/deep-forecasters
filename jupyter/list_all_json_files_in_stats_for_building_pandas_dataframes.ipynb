# %%
import os

# %%
# a list of all subfolders in stats/
subfolders_list = os.listdir(path='../stats/')

# %%
# sort the subfolders list in place
subfolders_list.sort()

# %%
len(subfolders_list)
# Out:
# 499

# %%
dataset = 'test'

# %%
for subfolder in subfolders_list:
    print('python predictions_json_to_pandas.py --model_id={} --execution={} --dataset={}'.format(subfolder[:-3],
                                                                                                  int(subfolder[-2:]),
                                                                                                  dataset))
# Out:
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=0 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=1 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=2 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=3 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=4 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=5 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=6 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=7 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=8 --dataset=test
# python predictions_json_to_pandas.py --model_id=DMSLSTM_TPU_10 --execution=9 --dataset=test
# ...
