# %%
! ls -l /home/developer/gcp/cbidmltsf/database/rename_files.dat
# Out:
# -rw-rw-r-- 1 developer developer 8000 jun 14 17:59 /home/developer/gcp/cbidmltsf/database/rename_files.dat

# %%
filename = '/home/developer/gcp/cbidmltsf/database/rename_files.dat'

# %%
no_targets = 24

# %%
strings_list = list()

# %%
with open(filename) as fp:
    lines = fp.readlines()
    for line in lines:
        # count += 1
        line = line.strip()
        new_line = '{}_{:03d}{}'.format(line[:-4], no_targets, line[-4:])
        print('mv {} {}'.format(line.strip(), new_line))
# Out:
# mv ARTRFDC_TPU_000_00_on_test_tfrecord.pkl ARTRFDC_TPU_000_00_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_01_on_test_tfrecord.pkl ARTRFDC_TPU_000_01_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_02_on_test_tfrecord.pkl ARTRFDC_TPU_000_02_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_03_on_test_tfrecord.pkl ARTRFDC_TPU_000_03_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_04_on_test_tfrecord.pkl ARTRFDC_TPU_000_04_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_05_on_test_tfrecord.pkl ARTRFDC_TPU_000_05_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_06_on_test_tfrecord.pkl ARTRFDC_TPU_000_06_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_07_on_test_tfrecord.pkl ARTRFDC_TPU_000_07_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_08_on_test_tfrecord.pkl ARTRFDC_TPU_000_08_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_000_09_on_test_tfrecord.pkl ARTRFDC_TPU_000_09_on_test_tfrecord_024.pkl
# mv ARTRFDC_TPU_001_00_on_test_tfrecord.pkl ARTRFDC_TPU_001_00_on_test_tfrecord_024.pkl
# ...
