# %% [markdown]
# ### load predictions detail pickles and compare models over a consistent period

# %%
import json
import numpy as np
import pandas as pd
import os

# %%
from bokeh.plotting import figure, show, output_file, save
from bokeh.io import output_notebook
# select a palette
from bokeh.palettes import d3
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# load all available pickles in database/predictions_detail/ by building a files list
avail_pkl_list = os.listdir(path='/home/developer/gcp/cbidmltsf/database/predictions_detail/')
avail_pkl_list.sort()
avail_pkl_list

print('{} pickle files available in database/predictions_detail/'.format(len(avail_pkl_list)))
# Out:
# 80 pickle files available in database/predictions_detail/

# %%
# a Pandas dataframe to store all predictions detail items
df_columns = ['model_id',
              'execution',
              'dataset',
              'inference',
              'string_timestamps',
              'predictions',
              'targets',
              'mae',
              'rmse',
              'smape']

df = pd.DataFrame(columns=df_columns)

# %% [markdown]
# ### trim the inference rows produced over the test dataset to a given number

# %%
rows_to_trim = 504

# %%
# collect prediction items from all available pickle files into a single dataframe
for available_pickle in avail_pkl_list:
    buffer_df = pd.read_pickle('../database/predictions_detail/{}'.format(available_pickle))[:rows_to_trim]
    # append buffer to final dataframe
    df = df.append(buffer_df, ignore_index=True)

# %% [markdown]
# ### group all selected rows for each model, execution, dataset, and inference

# %%
# build a predictions summary over the selected number of rows,
# reset index to avoid making a multi-column index when grouping by
trimmed_summary_df = df.groupby(['model_id',
                                 'execution',
                                 'dataset',
                                 'inference']).mean().reset_index()

# %% [markdown]
# ### now consolidate executions, grouping by model, dataset, and inference

# %%
grouped = trimmed_summary_df.groupby(['model_id', 'dataset', 'inference']).mean().reset_index()

# %%
# an empty dataframe to store performance metrics values per model_id-dataset-inference
metrics_columns = [
    'model_id',
    'dataset',
    'inference',
    'count',
    # 'mae_min',
    # 'mae_mean',
    # 'mae_max',
    # 'mae_std',
    # 'rmse_min',
    # 'rmse_mean',
    # 'rmse_max',
    # 'rmse_std',
    'smape_min',
    'smape_mean',
    'smape_max',
    'smape_std',
    # 'mae_vector',
    # 'rmse_vector',
    # 'smape_vector'
]

metrics_df = pd.DataFrame(columns=metrics_columns)

# %%
for _, row in grouped.iterrows():

    model_id, dataset, inference = row['model_id'], row['dataset'], row['inference']
        
    # print (model_id, dataset, inference)
    # get a boolean to filter prediction_results_df on the model_id, dataset, and inference
    flag = \
    trimmed_summary_df.model_id.eq(model_id) & \
    trimmed_summary_df.dataset.eq(dataset) & \
    trimmed_summary_df.inference.eq(inference)

    filtered_df = trimmed_summary_df[flag]

    # a row dataframe to calculate metrics for a given model_id, dataset, and inference
    row_df = pd.DataFrame([[
        model_id,
        dataset,
        inference,
        filtered_df.execution.count(),
        # filtered_df.mae.min(),
        # filtered_df.mae.mean(),
        # filtered_df.mae.max(),
        # filtered_df.mae.std(),
        # filtered_df.rmse.min(),
        # filtered_df.rmse.mean(),
        # filtered_df.rmse.max(),
        # filtered_df.rmse.std(),
        filtered_df.smape.min(),
        filtered_df.smape.mean(),
        filtered_df.smape.max(),
        filtered_df.smape.std(),
        # np.mean(np.array([row.mae_vector for _, row in filtered_df.iterrows()]), axis=0),
        # np.mean(np.array([row.rmse_vector for _, row in filtered_df.iterrows()]), axis=0),
        # np.mean(np.array([row.smape_vector for _, row in filtered_df.iterrows()]), axis=0),
    ]],
        columns=metrics_columns)
    
    metrics_df = metrics_df.append(row_df, ignore_index=True)

# %%
# best metrics for 24-step-ahead
metrics_df[metrics_df['inference'] == '024'].style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col5 {
#             background-color:  lightgreen;
#         }    #T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col6 {
#             background-color:  lightgreen;
#         }    #T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col7 {
#             background-color:  lightgreen;
#         }    #T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col4 {
#             background-color:  lightgreen;
#         }</style><table id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col2" class="data row0 col2" >024</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col4" class="data row0 col4" >0.037532</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col5" class="data row0 col5" >0.041544</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col6" class="data row0 col6" >0.046844</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row0_col7" class="data row0 col7" >0.003603</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col2" class="data row1 col2" >024</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col3" class="data row1 col3" >10</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col4" class="data row1 col4" >0.043127</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col5" class="data row1 col5" >0.046446</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col6" class="data row1 col6" >0.048679</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row1_col7" class="data row1 col7" >0.001962</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col0" class="data row2 col0" >DMSLSTM_TPU_006</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col1" class="data row2 col1" >test</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col2" class="data row2 col2" >024</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col3" class="data row2 col3" >10</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col4" class="data row2 col4" >0.032036</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col5" class="data row2 col5" >0.032353</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col6" class="data row2 col6" >0.032540</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row2_col7" class="data row2 col7" >0.000195</td>
#             </tr>
#             <tr>
#                         <th id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col0" class="data row3 col0" >EDSLSTM_TPU_011</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col1" class="data row3 col1" >test</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col2" class="data row3 col2" >024</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col3" class="data row3 col3" >10</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col4" class="data row3 col4" >0.031777</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col5" class="data row3 col5" >0.068875</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col6" class="data row3 col6" >0.387734</td>
#                         <td id="T_fc9b89fe_d38c_11eb_a476_55d5f6dc84c2row3_col7" class="data row3 col7" >0.112041</td>
#             </tr>
#     </tbody></table>

# %%
# worst metrics for 24-step-ahead
metrics_df[metrics_df['inference'] == '024'].style.highlight_max(color = 'yellow', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col4 {
#             background-color:  yellow;
#         }    #T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col5 {
#             background-color:  yellow;
#         }    #T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col6 {
#             background-color:  yellow;
#         }    #T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col7 {
#             background-color:  yellow;
#         }</style><table id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col2" class="data row0 col2" >024</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col4" class="data row0 col4" >0.037532</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col5" class="data row0 col5" >0.041544</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col6" class="data row0 col6" >0.046844</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row0_col7" class="data row0 col7" >0.003603</td>
#             </tr>
#             <tr>
#                         <th id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col2" class="data row1 col2" >024</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col3" class="data row1 col3" >10</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col4" class="data row1 col4" >0.043127</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col5" class="data row1 col5" >0.046446</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col6" class="data row1 col6" >0.048679</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row1_col7" class="data row1 col7" >0.001962</td>
#             </tr>
#             <tr>
#                         <th id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2level0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col0" class="data row2 col0" >DMSLSTM_TPU_006</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col1" class="data row2 col1" >test</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col2" class="data row2 col2" >024</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col3" class="data row2 col3" >10</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col4" class="data row2 col4" >0.032036</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col5" class="data row2 col5" >0.032353</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col6" class="data row2 col6" >0.032540</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row2_col7" class="data row2 col7" >0.000195</td>
#             </tr>
#             <tr>
#                         <th id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2level0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col0" class="data row3 col0" >EDSLSTM_TPU_011</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col1" class="data row3 col1" >test</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col2" class="data row3 col2" >024</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col3" class="data row3 col3" >10</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col4" class="data row3 col4" >0.031777</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col5" class="data row3 col5" >0.068875</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col6" class="data row3 col6" >0.387734</td>
#                         <td id="T_fd4ea89a_d38c_11eb_a476_55d5f6dc84c2row3_col7" class="data row3 col7" >0.112041</td>
#             </tr>
#     </tbody></table>

# %%
# best metrics for 48-step-ahead
metrics_df[metrics_df['inference'] == '048'].style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col4 {
#             background-color:  lightgreen;
#         }    #T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col5 {
#             background-color:  lightgreen;
#         }    #T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col6 {
#             background-color:  lightgreen;
#         }    #T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col7 {
#             background-color:  lightgreen;
#         }</style><table id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col2" class="data row0 col2" >048</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col4" class="data row0 col4" >0.041624</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col5" class="data row0 col5" >0.047879</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col6" class="data row0 col6" >0.055085</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row0_col7" class="data row0 col7" >0.004484</td>
#             </tr>
#             <tr>
#                         <th id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col2" class="data row1 col2" >048</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col3" class="data row1 col3" >10</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col4" class="data row1 col4" >0.047635</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col5" class="data row1 col5" >0.052956</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col6" class="data row1 col6" >0.056466</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row1_col7" class="data row1 col7" >0.002930</td>
#             </tr>
#             <tr>
#                         <th id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col0" class="data row2 col0" >DMSLSTM_TPU_007</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col1" class="data row2 col1" >test</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col2" class="data row2 col2" >048</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col3" class="data row2 col3" >10</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col4" class="data row2 col4" >0.032846</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col5" class="data row2 col5" >0.033206</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col6" class="data row2 col6" >0.033623</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row2_col7" class="data row2 col7" >0.000245</td>
#             </tr>
#             <tr>
#                         <th id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2level0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col0" class="data row3 col0" >EDSLSTM_TPU_012</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col1" class="data row3 col1" >test</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col2" class="data row3 col2" >048</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col3" class="data row3 col3" >10</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col4" class="data row3 col4" >0.036294</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col5" class="data row3 col5" >0.087629</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col6" class="data row3 col6" >0.403293</td>
#                         <td id="T_fdecadf6_d38c_11eb_a476_55d5f6dc84c2row3_col7" class="data row3 col7" >0.118452</td>
#             </tr>
#     </tbody></table>

# %%
# worst metrics for 48-step-ahead
metrics_df[metrics_df['inference'] == '048'].style.highlight_max(color = 'yellow', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col4 {
#             background-color:  yellow;
#         }    #T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col5 {
#             background-color:  yellow;
#         }    #T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col6 {
#             background-color:  yellow;
#         }    #T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col7 {
#             background-color:  yellow;
#         }</style><table id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col1" class="data row0 col1" >test</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col2" class="data row0 col2" >048</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col3" class="data row0 col3" >10</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col4" class="data row0 col4" >0.041624</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col5" class="data row0 col5" >0.047879</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col6" class="data row0 col6" >0.055085</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row0_col7" class="data row0 col7" >0.004484</td>
#             </tr>
#             <tr>
#                         <th id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2level0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col1" class="data row1 col1" >test</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col2" class="data row1 col2" >048</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col3" class="data row1 col3" >10</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col4" class="data row1 col4" >0.047635</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col5" class="data row1 col5" >0.052956</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col6" class="data row1 col6" >0.056466</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row1_col7" class="data row1 col7" >0.002930</td>
#             </tr>
#             <tr>
#                         <th id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2level0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col0" class="data row2 col0" >DMSLSTM_TPU_007</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col1" class="data row2 col1" >test</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col2" class="data row2 col2" >048</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col3" class="data row2 col3" >10</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col4" class="data row2 col4" >0.032846</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col5" class="data row2 col5" >0.033206</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col6" class="data row2 col6" >0.033623</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row2_col7" class="data row2 col7" >0.000245</td>
#             </tr>
#             <tr>
#                         <th id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2level0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col0" class="data row3 col0" >EDSLSTM_TPU_012</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col1" class="data row3 col1" >test</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col2" class="data row3 col2" >048</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col3" class="data row3 col3" >10</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col4" class="data row3 col4" >0.036294</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col5" class="data row3 col5" >0.087629</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col6" class="data row3 col6" >0.403293</td>
#                         <td id="T_fe8767ce_d38c_11eb_a476_55d5f6dc84c2row3_col7" class="data row3 col7" >0.118452</td>
#             </tr>
#     </tbody></table>
