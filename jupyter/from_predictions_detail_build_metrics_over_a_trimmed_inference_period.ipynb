# %% [markdown]
# ### load predictions detail pickles and compare models over a consistent period

# %%
import json
import numpy as np
import pandas as pd
import os

# %%
from bokeh.plotting import figure, show, output_file, save
from bokeh.io import output_notebook
# select a palette
from bokeh.palettes import d3
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
# load all available pickles in database/predictions_detail/ by building a files list
avail_pkl_list = os.listdir(path='/home/developer/gcp/cbidmltsf/database/predictions_detail/')
avail_pkl_list.sort()
avail_pkl_list

print('{} pickle files available in database/predictions_detail/'.format(len(avail_pkl_list)))
# Out:
# 80 pickle files available in database/predictions_detail/

# %%
# a Pandas dataframe to store all predictions detail items
df_columns = ['model_id',
              'execution',
              'dataset',
              'inference',
              'string_timestamps',
              'predictions',
              'targets',
              'mae',
              'rmse',
              'smape']

df = pd.DataFrame(columns=df_columns)

# %% [markdown]
# ### trim the inference rows produced over the test dataset to a given number

# %%
rows_to_trim = 168

# %%
# collect prediction items from all available pickle files into a single dataframe
for available_pickle in avail_pkl_list:
    buffer_df = pd.read_pickle('../database/predictions_detail/{}'.format(available_pickle))[:rows_to_trim]
    # append buffer to final dataframe
    df = df.append(buffer_df, ignore_index=True)

# %%
df
# Out:
#               model_id execution dataset inference  \
# 0      ARTRFDC_TPU_000         0    test       024
# 1      ARTRFDC_TPU_000         0    test       024
# 2      ARTRFDC_TPU_000         0    test       024
# 3      ARTRFDC_TPU_000         0    test       024
# 4      ARTRFDC_TPU_000         0    test       024
# ...                ...       ...     ...       ...
# 13435  EDSLSTM_TPU_012         9    test       048
# 13436  EDSLSTM_TPU_012         9    test       048
# 13437  EDSLSTM_TPU_012         9    test       048
# 13438  EDSLSTM_TPU_012         9    test       048
# 13439  EDSLSTM_TPU_012         9    test       048
#
#                                        string_timestamps  \
# 0      [2018-05-08 00:00:00, 2018-05-08 01:00:00, 201...
# 1      [2018-05-08 01:00:00, 2018-05-08 02:00:00, 201...
# 2      [2018-05-08 02:00:00, 2018-05-08 03:00:00, 201...
# 3      [2018-05-08 03:00:00, 2018-05-08 04:00:00, 201...
# 4      [2018-05-08 04:00:00, 2018-05-08 05:00:00, 201...
# ...                                                  ...
# 13435  [2018-05-10 11:00:00, 2018-05-10 12:00:00, 201...
# 13436  [2018-05-10 12:00:00, 2018-05-10 13:00:00, 201...
# 13437  [2018-05-10 13:00:00, 2018-05-10 14:00:00, 201...
# 13438  [2018-05-10 14:00:00, 2018-05-10 15:00:00, 201...
# 13439  [2018-05-10 15:00:00, 2018-05-10 16:00:00, 201...
#
#                                              predictions  \
# 0      [2149.200439453125, 1996.2294921875, 1900.8508...
# 1      [1975.03076171875, 1885.2646484375, 1824.51171...
# 2      [1822.8671875, 1772.877197265625, 1759.9060058...
# 3      [1748.633056640625, 1742.730224609375, 1779.09...
# 4      [1761.5634765625, 1788.3353271484375, 1936.010...
# ...                                                  ...
# 13435  [2584.451171875, 2676.203857421875, 2717.97607...
# 13436  [2683.687255859375, 2736.33154296875, 2743.760...
# 13437  [2745.304931640625, 2766.29248046875, 2749.001...
# 13438  [2784.90087890625, 2776.83837890625, 2738.9902...
# 13439  [2785.577392578125, 2749.22509765625, 2700.823...
#
#                                                  targets         mae  \
# 0      [2116.356689453125, 1893.3948974609375, 1790.4...  115.793541
# 1      [1893.3948974609375, 1790.4100341796875, 1775....  111.819374
# 2      [1790.4100341796875, 1775.4566650390625, 1747....  102.713097
# 3      [1775.4566650390625, 1747.455078125, 1770.9300...  104.318604
# 4      [1747.455078125, 1770.9300537109375, 1974.2517...  106.615181
# ...                                                  ...         ...
# 13435  [2599.05322265625, 2709.36328125, 2810.8715820...   87.010160
# 13436  [2709.36328125, 2810.87158203125, 2839.5864257...   86.092430
# 13437  [2810.87158203125, 2839.58642578125, 2773.3981...   83.922040
# 13438  [2839.58642578125, 2773.398193359375, 2784.179...   84.850225
# 13439  [2773.398193359375, 2784.179931640625, 2688.86...   85.102114
#
#              rmse     smape
# 0      178.249934  0.048070
# 1      176.953179  0.046238
# 2      175.296440  0.041710
# 3      176.140087  0.042744
# 4      176.006486  0.043861
# ...           ...       ...
# 13435  103.575266  0.038023
# 13436  101.546492  0.037774
# 13437   98.567697  0.037325
# 13438  100.769601  0.038291
# 13439  101.931822  0.038539
#
# [13440 rows x 10 columns]

# %%
# the default number of displayed rows for a dataframe is 60, expand it
pd.set_option("display.max_rows", 200)

# %%
### group all selected rows for each model, execution, dataset, and inference

# %%
# build a predictions summary over the selected number of rows,
# reset index to avoid making a multi-column index when grouping by
trimmed_summary_df = df.groupby(['model_id',
                                 'execution',
                                 'dataset',
                                 'inference']).mean().reset_index()

# %%
trimmed_summary_df
# Out:
#            model_id  execution dataset inference          mae         rmse  \
# 0   ARTRFDC_TPU_000          0    test       024   100.628027   127.771021
# 1   ARTRFDC_TPU_000          0    test       048   122.483976   156.383812
# 2   ARTRFDC_TPU_000          1    test       024   118.881263   150.492990
# 3   ARTRFDC_TPU_000          1    test       048   145.106863   181.366243
# 4   ARTRFDC_TPU_000          2    test       024    99.546443   121.553090
# 5   ARTRFDC_TPU_000          2    test       048   110.270467   136.435351
# 6   ARTRFDC_TPU_000          3    test       024   124.510783   155.129013
# 7   ARTRFDC_TPU_000          3    test       048   143.691809   181.774613
# 8   ARTRFDC_TPU_000          4    test       024    98.158190   121.179498
# 9   ARTRFDC_TPU_000          4    test       048   108.536374   135.176910
# 10  ARTRFDC_TPU_000          5    test       024    99.419128   123.129498
# 11  ARTRFDC_TPU_000          5    test       048   119.749545   146.846287
# 12  ARTRFDC_TPU_000          6    test       024    91.711336   115.414540
# 13  ARTRFDC_TPU_000          6    test       048    99.142980   126.694109
# 14  ARTRFDC_TPU_000          7    test       024    96.419092   122.408665
# 15  ARTRFDC_TPU_000          7    test       048   107.496467   137.868319
# 16  ARTRFDC_TPU_000          8    test       024   113.092821   139.321172
# 17  ARTRFDC_TPU_000          8    test       048   141.297608   170.991420
# 18  ARTRFDC_TPU_000          9    test       024   129.194253   157.107054
# 19  ARTRFDC_TPU_000          9    test       048   150.767387   183.597196
# 20  ARTRFDC_TPU_001          0    test       024   141.395424   182.183830
# 21  ARTRFDC_TPU_001          0    test       048   166.602039   214.082230
# 22  ARTRFDC_TPU_001          1    test       024   155.111349   190.523325
# 23  ARTRFDC_TPU_001          1    test       048   182.911060   221.851571
# 24  ARTRFDC_TPU_001          2    test       024   126.217930   160.774849
# 25  ARTRFDC_TPU_001          2    test       048   158.355990   199.554464
# 26  ARTRFDC_TPU_001          3    test       024   123.539381   153.082020
# 27  ARTRFDC_TPU_001          3    test       048   144.169170   176.014890
# 28  ARTRFDC_TPU_001          4    test       024   118.746568   148.634182
# 29  ARTRFDC_TPU_001          4    test       048   138.348055   174.757080
# 30  ARTRFDC_TPU_001          5    test       024   108.700388   138.951637
# 31  ARTRFDC_TPU_001          5    test       048   117.591235   151.848500
# 32  ARTRFDC_TPU_001          6    test       024   123.384505   161.909372
# 33  ARTRFDC_TPU_001          6    test       048   140.749948   187.620617
# 34  ARTRFDC_TPU_001          7    test       024   136.203596   163.077186
# 35  ARTRFDC_TPU_001          7    test       048   161.354656   189.491211
# 36  ARTRFDC_TPU_001          8    test       024   148.440074   181.329493
# 37  ARTRFDC_TPU_001          8    test       048   180.481450   213.958552
# 38  ARTRFDC_TPU_001          9    test       024   133.485092   171.332674
# 39  ARTRFDC_TPU_001          9    test       048   164.318675   208.189085
# 40  DMSLSTM_TPU_006          0    test       024    76.968083    93.201038
# 41  DMSLSTM_TPU_006          1    test       024    77.960302    94.326256
# 42  DMSLSTM_TPU_006          2    test       024    77.061537    93.372376
# 43  DMSLSTM_TPU_006          3    test       024    77.745791    93.794888
# 44  DMSLSTM_TPU_006          4    test       024    77.641695    93.803448
# 45  DMSLSTM_TPU_006          5    test       024    77.660363    94.291594
# 46  DMSLSTM_TPU_006          6    test       024    77.864935    94.368437
# 47  DMSLSTM_TPU_006          7    test       024    78.199099    94.566719
# 48  DMSLSTM_TPU_006          8    test       024    78.260972    95.031617
# 49  DMSLSTM_TPU_006          9    test       024    77.683404    93.891627
# 50  DMSLSTM_TPU_007          0    test       048    80.708906   100.251847
# 51  DMSLSTM_TPU_007          1    test       048    79.488233    98.807624
# 52  DMSLSTM_TPU_007          2    test       048    78.454698    97.854527
# 53  DMSLSTM_TPU_007          3    test       048    79.422789    98.852288
# 54  DMSLSTM_TPU_007          4    test       048    79.113887    98.311427
# 55  DMSLSTM_TPU_007          5    test       048    79.147015    98.391428
# 56  DMSLSTM_TPU_007          6    test       048    79.081200    98.204489
# 57  DMSLSTM_TPU_007          7    test       048    78.677405    98.280426
# 58  DMSLSTM_TPU_007          8    test       048    79.899541    98.813055
# 59  DMSLSTM_TPU_007          9    test       048    80.123142    99.234053
# 60  EDSLSTM_TPU_011          0    test       024    75.922059    98.694889
# 61  EDSLSTM_TPU_011          1    test       024    81.101511   105.625357
# 62  EDSLSTM_TPU_011          2    test       024    74.064721    95.985350
# 63  EDSLSTM_TPU_011          3    test       024    72.270148    93.857182
# 64  EDSLSTM_TPU_011          4    test       024    77.590509    99.483664
# 65  EDSLSTM_TPU_011          5    test       024  1192.672128  1261.173331
# 66  EDSLSTM_TPU_011          6    test       024    81.841686   105.047435
# 67  EDSLSTM_TPU_011          7    test       024    77.277620   100.251464
# 68  EDSLSTM_TPU_011          8    test       024    79.603934   103.342074
# 69  EDSLSTM_TPU_011          9    test       024    80.385863   102.389722
# 70  EDSLSTM_TPU_012          0    test       048   361.994403   412.004766
# 71  EDSLSTM_TPU_012          1    test       048    82.630831   109.908161
# 72  EDSLSTM_TPU_012          2    test       048    77.443594   102.574619
# 73  EDSLSTM_TPU_012          3    test       048    78.981469   104.614376
# 74  EDSLSTM_TPU_012          4    test       048  1016.567516  1111.994599
# 75  EDSLSTM_TPU_012          5    test       048    81.769689   110.076918
# 76  EDSLSTM_TPU_012          6    test       048    76.956490   104.112664
# 77  EDSLSTM_TPU_012          7    test       048    81.970684   107.965373
# 78  EDSLSTM_TPU_012          8    test       048    79.733271   107.108218
# 79  EDSLSTM_TPU_012          9    test       048    82.630586   111.980049
#
#        smape
# 0   0.042299
# 1   0.050592
# 2   0.049100
# 3   0.059062
# 4   0.042322
# 5   0.046266
# 6   0.050333
# 7   0.057502
# 8   0.040894
# 9   0.044649
# 10  0.041643
# 11  0.049458
# 12  0.038437
# 13  0.041292
# 14  0.040567
# 15  0.044613
# 16  0.046617
# 17  0.057484
# 18  0.053467
# 19  0.061494
# 20  0.056668
# 21  0.066284
# 22  0.064652
# 23  0.075184
# 24  0.052369
# 25  0.064938
# 26  0.050395
# 27  0.058415
# 28  0.048524
# 29  0.055901
# 30  0.044816
# 31  0.048469
# 32  0.049285
# 33  0.055202
# 34  0.056141
# 35  0.066231
# 36  0.059186
# 37  0.071842
# 38  0.054939
# 39  0.066977
# 40  0.032882
# 41  0.033372
# 42  0.032988
# 43  0.033301
# 44  0.033241
# 45  0.033215
# 46  0.033294
# 47  0.033409
# 48  0.033502
# 49  0.033291
# 50  0.034627
# 51  0.034052
# 52  0.033687
# 53  0.034059
# 54  0.033999
# 55  0.033937
# 56  0.033897
# 57  0.033711
# 58  0.034276
# 59  0.034339
# 60  0.030526
# 61  0.032298
# 62  0.029789
# 63  0.028936
# 64  0.031273
# 65  0.407490
# 66  0.032792
# 67  0.030941
# 68  0.031625
# 69  0.032088
# 70  0.154262
# 71  0.033912
# 72  0.031847
# 73  0.032644
# 74  0.407689
# 75  0.033670
# 76  0.031649
# 77  0.033689
# 78  0.032827
# 79  0.033872

# %% [markdown]
# ### now consolidate executions, grouping by model, dataset, and inference

# %%
grouped = df.groupby(['model_id', 'dataset', 'inference']).mean().reset_index()

# %%
grouped
# Out:
#           model_id dataset inference         mae        rmse     smape
# 0  ARTRFDC_TPU_000    test       024  107.156134  133.350654  0.044568
# 1  ARTRFDC_TPU_000    test       048  124.854348  155.713426  0.051241
# 2  ARTRFDC_TPU_001    test       024  131.522431  165.179857  0.053697
# 3  ARTRFDC_TPU_001    test       048  155.488228  193.736820  0.062944
# 4  DMSLSTM_TPU_006    test       024   77.704618   94.064800  0.033249
# 5  DMSLSTM_TPU_007    test       048   79.411681   98.700116  0.034058
# 6  EDSLSTM_TPU_011    test       024  189.273018  216.585047  0.068776
# 7  EDSLSTM_TPU_012    test       048  202.067853  238.233974  0.082606

# %%
# an empty dataframe to store performance metrics values per model_id-dataset-inference
metrics_columns = [
    'model_id',
    'dataset',
    'inference',
    'count',
    # 'mae_min',
    # 'mae_mean',
    # 'mae_max',
    # 'mae_std',
    # 'rmse_min',
    # 'rmse_mean',
    # 'rmse_max',
    # 'rmse_std',
    'smape_min',
    'smape_mean',
    'smape_max',
    'smape_std',
    # 'mae_vector',
    # 'rmse_vector',
    # 'smape_vector'
]

metrics_df = pd.DataFrame(columns=metrics_columns)

# %%
for _, row in grouped.iterrows():

    model_id, dataset, inference = row['model_id'], row['dataset'], row['inference']
        
    # print (model_id, dataset, inference)
    # get a boolean to filter prediction_results_df on the model_id, dataset, and inference
    flag = \
    trimmed_summary_df.model_id.eq(model_id) & \
    trimmed_summary_df.dataset.eq(dataset) & \
    trimmed_summary_df.inference.eq(inference)

    filtered_df = trimmed_summary_df[flag]

    # a row dataframe to calculate metrics for a given model_id, dataset, and inference
    row_df = pd.DataFrame([[
        model_id,
        dataset,
        inference,
        filtered_df.execution.count(),
        # filtered_df.mae.min(),
        # filtered_df.mae.mean(),
        # filtered_df.mae.max(),
        # filtered_df.mae.std(),
        # filtered_df.rmse.min(),
        # filtered_df.rmse.mean(),
        # filtered_df.rmse.max(),
        # filtered_df.rmse.std(),
        filtered_df.smape.min(),
        filtered_df.smape.mean(),
        filtered_df.smape.max(),
        filtered_df.smape.std(),
        # np.mean(np.array([row.mae_vector for _, row in filtered_df.iterrows()]), axis=0),
        # np.mean(np.array([row.rmse_vector for _, row in filtered_df.iterrows()]), axis=0),
        # np.mean(np.array([row.smape_vector for _, row in filtered_df.iterrows()]), axis=0),
    ]],
        columns=metrics_columns)
    
    metrics_df = metrics_df.append(row_df, ignore_index=True)

# %%
# best metrics for 24-step-ahead
metrics_df[metrics_df['inference'] == '024'].style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col5 {
#             background-color:  lightgreen;
#         }    #T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col6 {
#             background-color:  lightgreen;
#         }    #T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col7 {
#             background-color:  lightgreen;
#         }    #T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col4 {
#             background-color:  lightgreen;
#         }</style><table id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col2" class="data row0 col2" >024</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col3" class="data row0 col3" >10</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col4" class="data row0 col4" >0.038437</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col5" class="data row0 col5" >0.044568</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col6" class="data row0 col6" >0.053467</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow0_col7" class="data row0 col7" >0.004978</td>
#             </tr>
#             <tr>
#                         <th id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75flevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col2" class="data row1 col2" >024</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col3" class="data row1 col3" >10</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col4" class="data row1 col4" >0.044816</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col5" class="data row1 col5" >0.053697</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col6" class="data row1 col6" >0.064652</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow1_col7" class="data row1 col7" >0.005814</td>
#             </tr>
#             <tr>
#                         <th id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75flevel0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col0" class="data row2 col0" >DMSLSTM_TPU_006</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col2" class="data row2 col2" >024</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col3" class="data row2 col3" >10</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col4" class="data row2 col4" >0.032882</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col5" class="data row2 col5" >0.033249</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col6" class="data row2 col6" >0.033502</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow2_col7" class="data row2 col7" >0.000187</td>
#             </tr>
#             <tr>
#                         <th id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75flevel0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col0" class="data row3 col0" >EDSLSTM_TPU_011</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col1" class="data row3 col1" >test</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col2" class="data row3 col2" >024</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col3" class="data row3 col3" >10</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col4" class="data row3 col4" >0.028936</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col5" class="data row3 col5" >0.068776</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col6" class="data row3 col6" >0.407490</td>
#                         <td id="T_6fe9319a_d04a_11eb_b7a3_b32af11ba75frow3_col7" class="data row3 col7" >0.119018</td>
#             </tr>
#     </tbody></table>

# %%
# worst metrics for 24-step-ahead
metrics_df[metrics_df['inference'] == '024'].style.highlight_max(color = 'yellow', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col4 {
#             background-color:  yellow;
#         }    #T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col5 {
#             background-color:  yellow;
#         }    #T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col6 {
#             background-color:  yellow;
#         }    #T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col7 {
#             background-color:  yellow;
#         }</style><table id="T_703b1816_d04a_11eb_b7a3_b32af11ba75f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_703b1816_d04a_11eb_b7a3_b32af11ba75flevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col2" class="data row0 col2" >024</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col3" class="data row0 col3" >10</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col4" class="data row0 col4" >0.038437</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col5" class="data row0 col5" >0.044568</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col6" class="data row0 col6" >0.053467</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow0_col7" class="data row0 col7" >0.004978</td>
#             </tr>
#             <tr>
#                         <th id="T_703b1816_d04a_11eb_b7a3_b32af11ba75flevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col2" class="data row1 col2" >024</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col3" class="data row1 col3" >10</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col4" class="data row1 col4" >0.044816</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col5" class="data row1 col5" >0.053697</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col6" class="data row1 col6" >0.064652</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow1_col7" class="data row1 col7" >0.005814</td>
#             </tr>
#             <tr>
#                         <th id="T_703b1816_d04a_11eb_b7a3_b32af11ba75flevel0_row2" class="row_heading level0 row2" >4</th>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col0" class="data row2 col0" >DMSLSTM_TPU_006</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col2" class="data row2 col2" >024</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col3" class="data row2 col3" >10</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col4" class="data row2 col4" >0.032882</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col5" class="data row2 col5" >0.033249</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col6" class="data row2 col6" >0.033502</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow2_col7" class="data row2 col7" >0.000187</td>
#             </tr>
#             <tr>
#                         <th id="T_703b1816_d04a_11eb_b7a3_b32af11ba75flevel0_row3" class="row_heading level0 row3" >6</th>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col0" class="data row3 col0" >EDSLSTM_TPU_011</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col1" class="data row3 col1" >test</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col2" class="data row3 col2" >024</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col3" class="data row3 col3" >10</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col4" class="data row3 col4" >0.028936</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col5" class="data row3 col5" >0.068776</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col6" class="data row3 col6" >0.407490</td>
#                         <td id="T_703b1816_d04a_11eb_b7a3_b32af11ba75frow3_col7" class="data row3 col7" >0.119018</td>
#             </tr>
#     </tbody></table>

# %%
# best metrics for 48-step-ahead
metrics_df[metrics_df['inference'] == '048'].style.highlight_min(color = 'lightgreen', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col5 {
#             background-color:  lightgreen;
#         }    #T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col6 {
#             background-color:  lightgreen;
#         }    #T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col7 {
#             background-color:  lightgreen;
#         }    #T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col4 {
#             background-color:  lightgreen;
#         }</style><table id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75flevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col2" class="data row0 col2" >048</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col3" class="data row0 col3" >10</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col4" class="data row0 col4" >0.041292</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col5" class="data row0 col5" >0.051241</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col6" class="data row0 col6" >0.061494</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow0_col7" class="data row0 col7" >0.007143</td>
#             </tr>
#             <tr>
#                         <th id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75flevel0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col2" class="data row1 col2" >048</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col3" class="data row1 col3" >10</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col4" class="data row1 col4" >0.048469</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col5" class="data row1 col5" >0.062944</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col6" class="data row1 col6" >0.075184</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow1_col7" class="data row1 col7" >0.008238</td>
#             </tr>
#             <tr>
#                         <th id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75flevel0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col0" class="data row2 col0" >DMSLSTM_TPU_007</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col2" class="data row2 col2" >048</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col3" class="data row2 col3" >10</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col4" class="data row2 col4" >0.033687</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col5" class="data row2 col5" >0.034058</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col6" class="data row2 col6" >0.034627</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow2_col7" class="data row2 col7" >0.000289</td>
#             </tr>
#             <tr>
#                         <th id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75flevel0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col0" class="data row3 col0" >EDSLSTM_TPU_012</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col1" class="data row3 col1" >test</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col2" class="data row3 col2" >048</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col3" class="data row3 col3" >10</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col4" class="data row3 col4" >0.031649</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col5" class="data row3 col5" >0.082606</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col6" class="data row3 col6" >0.407689</td>
#                         <td id="T_709e2fd2_d04a_11eb_b7a3_b32af11ba75frow3_col7" class="data row3 col7" >0.120413</td>
#             </tr>
#     </tbody></table>

# %%
# worst metrics for 48-step-ahead
metrics_df[metrics_df['inference'] == '048'].style.highlight_max(color = 'yellow', axis = 0)
# Out:
# <style  type="text/css" >
#     #T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col4 {
#             background-color:  yellow;
#         }    #T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col5 {
#             background-color:  yellow;
#         }    #T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col6 {
#             background-color:  yellow;
#         }    #T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col7 {
#             background-color:  yellow;
#         }</style><table id="T_71008862_d04a_11eb_b7a3_b32af11ba75f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model_id</th>        <th class="col_heading level0 col1" >dataset</th>        <th class="col_heading level0 col2" >inference</th>        <th class="col_heading level0 col3" >count</th>        <th class="col_heading level0 col4" >smape_min</th>        <th class="col_heading level0 col5" >smape_mean</th>        <th class="col_heading level0 col6" >smape_max</th>        <th class="col_heading level0 col7" >smape_std</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_71008862_d04a_11eb_b7a3_b32af11ba75flevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col0" class="data row0 col0" >ARTRFDC_TPU_000</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col1" class="data row0 col1" >test</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col2" class="data row0 col2" >048</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col3" class="data row0 col3" >10</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col4" class="data row0 col4" >0.041292</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col5" class="data row0 col5" >0.051241</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col6" class="data row0 col6" >0.061494</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow0_col7" class="data row0 col7" >0.007143</td>
#             </tr>
#             <tr>
#                         <th id="T_71008862_d04a_11eb_b7a3_b32af11ba75flevel0_row1" class="row_heading level0 row1" >3</th>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col0" class="data row1 col0" >ARTRFDC_TPU_001</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col1" class="data row1 col1" >test</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col2" class="data row1 col2" >048</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col3" class="data row1 col3" >10</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col4" class="data row1 col4" >0.048469</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col5" class="data row1 col5" >0.062944</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col6" class="data row1 col6" >0.075184</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow1_col7" class="data row1 col7" >0.008238</td>
#             </tr>
#             <tr>
#                         <th id="T_71008862_d04a_11eb_b7a3_b32af11ba75flevel0_row2" class="row_heading level0 row2" >5</th>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col0" class="data row2 col0" >DMSLSTM_TPU_007</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col1" class="data row2 col1" >test</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col2" class="data row2 col2" >048</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col3" class="data row2 col3" >10</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col4" class="data row2 col4" >0.033687</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col5" class="data row2 col5" >0.034058</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col6" class="data row2 col6" >0.034627</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow2_col7" class="data row2 col7" >0.000289</td>
#             </tr>
#             <tr>
#                         <th id="T_71008862_d04a_11eb_b7a3_b32af11ba75flevel0_row3" class="row_heading level0 row3" >7</th>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col0" class="data row3 col0" >EDSLSTM_TPU_012</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col1" class="data row3 col1" >test</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col2" class="data row3 col2" >048</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col3" class="data row3 col3" >10</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col4" class="data row3 col4" >0.031649</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col5" class="data row3 col5" >0.082606</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col6" class="data row3 col6" >0.407689</td>
#                         <td id="T_71008862_d04a_11eb_b7a3_b32af11ba75frow3_col7" class="data row3 col7" >0.120413</td>
#             </tr>
#     </tbody></table>
