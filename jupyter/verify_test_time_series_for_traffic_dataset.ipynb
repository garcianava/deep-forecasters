# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
from bokeh.plotting import figure, show, output_file, save
from bokeh.io import output_notebook
from bokeh.layouts import row, gridplot, layout
from bokeh.palettes import d3
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
PROJECT_ROOT = '/home/developer/gcp/cbidmltsf'

# %%
data_folder = '{}/datasets/traffic/PEMS-SF'.format(PROJECT_ROOT)
data_folder
# Out:
# '/home/developer/gcp/cbidmltsf/datasets/traffic/PEMS-SF'

# %%
raw_ts_folder = '{}/datasets/traffic/separated_raw'.format(PROJECT_ROOT)
raw_ts_folder
# Out:
# '/home/developer/gcp/cbidmltsf/datasets/traffic/separated_raw'

# %%
def process_list(s, variable_type=int, delimiter=None):
    """Parses a line in the PEMS format to a list."""
    if delimiter is None:
      l = [
          variable_type(i) for i in s.replace('[', '').replace(']', '').split()
      ]
    else:
      l = [
          variable_type(i)
          for i in s.replace('[', '').replace(']', '').split(delimiter)
      ]

    return l

# %%
def read_single_list(filename):
    """Returns single list from a file in the PEMS-custom format."""
    with open(os.path.join(data_folder, filename), 'r') as dat:
        l = process_list(dat.readlines()[0])
    return l

# %%
stations_list = [id for id in read_single_list('stations_list')]
len(stations_list)
# Out:
# 963

# %%
test_ts_dir = '{}/sldbs/PEMS-SF_SEPARATED_FULL_BSCTRFM_168_168_07DB_MMX/test'.format(PROJECT_ROOT)
test_ts_dir
# Out:
# '/home/developer/gcp/cbidmltsf/sldbs/PEMS-SF_SEPARATED_FULL_BSCTRFM_168_168_07DB_MMX/test'

# %%
test_ts = pd.read_pickle('{}/ST_400000.pkl'.format(test_ts_dir))
test_ts
# Out:
#           id  sequential_id  occupancy_scaled  sin_hours_from_start  \
# 3648  400000              0          0.010404         -6.888165e-01
# 3649  400000              0          0.009777         -6.877184e-01
# 3650  400000              0          0.015509         -6.866187e-01
# 3651  400000              0          0.035642         -6.855175e-01
# 3652  400000              0          0.122387         -6.844147e-01
# ...      ...            ...               ...                   ...
# 4146  400000              0          0.091658         -6.054586e-03
# 4147  400000              0          0.078509         -4.540952e-03
# 4148  400000              0          0.061844         -3.027307e-03
# 4149  400000              0          0.037809         -1.513655e-03
# 4150  400000              0          0.022493         -2.449294e-16
#
#       cos_hours_from_start  sin_hour_day  cos_hour_day  sin_day_week  \
# 3648              0.724936      0.258819      0.965926     -0.781831
# 3649              0.725978      0.500000      0.866025     -0.781831
# 3650              0.727018      0.707107      0.707107     -0.781831
# 3651              0.728056      0.866025      0.500000     -0.781831
# 3652              0.729093      0.965926      0.258819     -0.781831
# ...                    ...           ...           ...           ...
# 4146              0.999982     -0.965926      0.258819     -0.974928
# 4147              0.999990     -0.866025      0.500000     -0.974928
# 4148              0.999995     -0.707107      0.707107     -0.974928
# 4149              0.999999     -0.500000      0.866025     -0.974928
# 4150              1.000000     -0.258819      0.965926     -0.974928
#
#       cos_day_week
# 3648      0.623490
# 3649      0.623490
# 3650      0.623490
# 3651      0.623490
# 3652      0.623490
# ...            ...
# 4146     -0.222521
# 4147     -0.222521
# 4148     -0.222521
# 4149     -0.222521
# 4150     -0.222521
#
# [503 rows x 9 columns]

# %%
def plot_line(title, x, y, width, height, x_label, y_label):
    p = figure(
        title=title,
        plot_width=width,
        plot_height=height,
        # tools='',
        # x_axis_type='datetime'
    )
    p.grid.grid_line_alpha=0.3

    p.xaxis.axis_label = x_label
    p.yaxis.axis_label = y_label

    p.line(x,
           y,
           color='red',
           )

    return p

# %%
show(
    plot_line(
        title = 'ST_400000 test time series',
        x=test_ts.index,
        y= test_ts.occupancy_scaled,
        width=720,
        height=240,
        x_label='Index',
        y_label='Car occupancy (scaled)'
))
# Out:
#   <div class="bk-root" id="efc34f35-fd47-4c1f-80b5-3e9f46c2c1eb" data-root-id="1002"></div>

# %%
test_ts.describe()
# Out:
#        sequential_id  occupancy_scaled  sin_hours_from_start  \
# count          503.0        503.000000          5.030000e+02
# mean             0.0          0.107841         -3.619606e-01
# std              0.0          0.067119          2.015330e-01
# min              0.0          0.000963         -6.888165e-01
# 25%              0.0          0.038652         -5.395405e-01
# 50%              0.0          0.128504         -3.708532e-01
# 75%              0.0          0.165374         -1.888233e-01
# max              0.0          0.334891         -2.449294e-16
#
#        cos_hours_from_start  sin_hour_day  cos_hour_day  sin_day_week  \
# count            503.000000  5.030000e+02  5.030000e+02  5.030000e+02
# mean               0.906422 -7.316877e-17 -1.988072e-03  1.554337e-03
# std                0.082835  7.085140e-01  7.071040e-01  7.076524e-01
# min                0.724936 -1.000000e+00 -1.000000e+00 -9.749279e-01
# 25%                0.841959 -7.071068e-01 -7.071068e-01 -7.818315e-01
# 50%                0.928691  1.224647e-16 -1.836970e-16 -2.449294e-16
# 75%                0.982011  7.071068e-01  7.071068e-01  7.818315e-01
# max                1.000000  1.000000e+00  1.000000e+00  9.749279e-01
#
#        cos_day_week
# count    503.000000
# mean      -0.001240
# std        0.707966
# min       -0.900969
# 25%       -0.900969
# 50%       -0.222521
# 75%        0.623490
# max        1.000000
